# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('2019_nCoV_data.csv')

# %%
data.head()
# Out:
#    Sno Province/State Country      Last Update  Confirmed  Deaths  Recovered
# 0    1          Anhui   China  1/22/2020 12:00        1.0     0.0        0.0
# 1    2        Beijing   China  1/22/2020 12:00       14.0     0.0        0.0
# 2    3      Chongqing   China  1/22/2020 12:00        6.0     0.0        0.0
# 3    4         Fujian   China  1/22/2020 12:00        1.0     0.0        0.0
# 4    5          Gansu   China  1/22/2020 12:00        0.0     0.0        0.0

# %%
data.tail()
# Out:
#      Sno   Province/State    Country      Last Update  Confirmed  Deaths  \
# 363  364  New South Wales  Australia  1/29/2020 21:00        4.0     0.0
# 364  365         Victoria  Australia  1/29/2020 21:00        2.0     0.0
# 365  366       Queensland  Australia  1/29/2020 21:00        1.0     0.0
# 366  367          Bavaria    Germany  1/29/2020 21:00        4.0     0.0
# 367  368              NaN    Finland  1/29/2020 21:00        1.0     0.0
#
#      Recovered
# 363        0.0
# 364        0.0
# 365        0.0
# 366        0.0
# 367        0.0

# %%
data.drop('Sno',axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 6 columns):
# Province/State    302 non-null object
# Country           368 non-null object
# Last Update       368 non-null object
# Confirmed         368 non-null float64
# Deaths            368 non-null float64
# Recovered         368 non-null float64
# dtypes: float64(3), object(3)
# memory usage: 17.3+ KB

# %%
data.describe()
# Out:
#          Confirmed      Deaths   Recovered
# count   368.000000  368.000000  368.000000
# mean     68.638587    1.600543    1.290761
# std     348.146908   12.819038    7.721637
# min       0.000000    0.000000    0.000000
# 25%       2.000000    0.000000    0.000000
# 50%       7.000000    0.000000    0.000000
# 75%      33.500000    0.000000    0.000000
# max    4586.000000  162.000000   90.000000

# %%
plt.figure(figsize=(30,20))
sns.countplot(x='Country',data=data)

# %%
plt.figure(figsize=(30,20))
sns.barplot(x='Country',y='Deaths',data=data)

# %%
plt.figure(figsize=(30,20))
sns.barplot(x='Country',y='Recovered',data=data)

# %%
sns.heatmap(data.corr(),cmap='coolwarm',annot=True)

# %%
sns.pairplot(data)

# %%
data['Deaths'].sum()
# Out:
# 589.0

# %%
data['Confirmed'].sum()
# Out:
# 25259.0

# %%
data['Recovered'].sum()
# Out:
# 475.0

# %%
data.plot(x='Last Update',y='Confirmed',figsize=(12,6))
data.plot(x='Last Update',y='Deaths',figsize=(12,6))
data.plot(x='Last Update',y='Recovered',figsize=(12,6))

# %%
# Where the most of the deaths happened

# %%
data.groupby('Province/State').sum()['Deaths'].sort_values(ascending=False).head()
# Out:
# Province/State
# Hubei           556.0
# Henan             7.0
# Hebei             7.0
# Heilongjiang      5.0
# Shanghai          5.0
# Name: Deaths, dtype: float64
